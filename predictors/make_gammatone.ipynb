# %%
"""Generate high-resolution gammatone spectrograms"""
from pathlib import Path

# %%
import eelbrain

# %%
# Define paths to data
DATA_ROOT = Path("~").expanduser() / 'Data' / 'cocoha'
STIMULUS_DIR = DATA_ROOT / 'stimuli'

# %%
# load all the stimuli in the stimulus directory excluding .wav suffix
STIMULI_PATHS = [stimulus.stem for stimulus in STIMULUS_DIR.glob("*.wav")]

# %%
# approx. 20 min in total

# Loop through the stimuli
for path in STIMULI_PATHS:
    # Define a filename for the gammatone spectrogram corresponding to this predictor.
    dst = STIMULUS_DIR / f'{path}-gammatone.pickle'
    # If the file already exists, we can skip it
    if dst.exists():
        print(f"Gammatone spectrogram for {path} already exists at {dst}, skipping.")
        continue
    # Load the sound file corresponding to the predictor
    wav = eelbrain.load.wav(STIMULUS_DIR / f'{path}')
    # Apply a gammatone filterbank, producing a high resolution spectrogram
    gt = eelbrain.gammatone_bank(wav, 80, 15000, 128, location='left', tstep=0.001)
    # Save the gammatone spectrogram at the intended destination
    eelbrain.save.pickle(gt, dst)
    print(f"Saved gammatone spectrogram for {path} at {dst}")
# Out:
# Gammatone spectrogram for marianne_story5_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_22 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_22-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_23 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_23-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_21 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_21-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_20 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_20-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_13 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_13-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_24 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_24-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_18 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_18-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_19 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_19-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_25 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_25-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_12 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_12-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_26 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_26-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story4_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story4_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story1_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story1_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story1_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story1_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story1_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story1_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story3_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story3_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story6_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story6_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_17 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_17-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_17 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_17-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_12 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_12-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_7 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_7-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_16 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_16-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_16 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_16-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story2_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story2_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story2_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story2_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_14 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_14-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_14 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_14-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_13 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_13-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_12 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_12-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story1_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story1_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_15 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_15-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story2_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story2_trial_8-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_15 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_15-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story2_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story2_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story2_trial_6 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story2_trial_6-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_11 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_11-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_1 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_1-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_10 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_10-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_9 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_9-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_12 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_12-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story2_trial_5 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story2_trial_5-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_12 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_12-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_3 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_3-gammatone.pickle, skipping.
# Gammatone spectrogram for dss already exists at /Users/sylvestereley/Data/cocoha/stimuli/dss-gammatone.pickle, skipping.
# Gammatone spectrogram for aske_story5_trial_2 already exists at /Users/sylvestereley/Data/cocoha/stimuli/aske_story5_trial_2-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story4_trial_13 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story4_trial_13-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story2_trial_4 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story2_trial_4-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story3_trial_13 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story3_trial_13-gammatone.pickle, skipping.
# Gammatone spectrogram for marianne_story5_trial_8 already exists at /Users/sylvestereley/Data/cocoha/stimuli/marianne_story5_trial_8-gammatone.pickle, skipping.
