# %%
import sys
# Add parent directory to path to import file_paths module
sys.path.insert(0, '..')
import file_paths
import helper_functions

import eelbrain

SUBJECTS = helper_functions.get_subjects()

# %%
# Loop through subjects to estimate TRFs

for SUBJECT in SUBJECTS:
    print("-" * 50)
    print(f"Processing subject {SUBJECT}...")
    
    # Check if all TRF files already exist
    trf_dir = file_paths.TRF_DIR / f"{SUBJECT}"
    trf_attended_path = trf_dir / f"{SUBJECT}_attended_preprocessed_eeg.pickle"
    trf_unattended_path = trf_dir / f"{SUBJECT}_unattended_preprocessed_eeg.pickle"
    
    if all([
        trf_attended_path.exists(), 
        trf_unattended_path.exists(), 
    ]):
        print(f"All TRF files for {SUBJECT} already exist, skipping.")
        continue
    
    # Load EEG data from pickle files
    eeg_path = file_paths.EEG_DIR / SUBJECT / f"{SUBJECT}_eeg_preproc.pickle"
    eeg = eelbrain.load.unpickle(eeg_path)


    # Load envelope data (all 4 versions)
    attended_envelope_path = file_paths.ENVELOPES_DIR / SUBJECT / f"{SUBJECT}_attended_envelope.pickle"
    unattended_envelope_path = file_paths.ENVELOPES_DIR / SUBJECT / f"{SUBJECT}_unattended_envelope.pickle"
    
    attended_envelope = eelbrain.load.unpickle(attended_envelope_path)
    unattended_envelope = eelbrain.load.unpickle(unattended_envelope_path)


    print(f"EEG: {eeg}")
    print(f"Attended envelope: {attended_envelope}")
    print(f"Unattended envelope: {unattended_envelope}")

    # Estimate TRFs for attended and unattended conditions using boosting
    print("Estimating attended TRF...")
    trf_attended = eelbrain.boosting(
            eeg,
            attended_envelope,
            -0.100,
            1.000,
            error='l1',
            basis=0.050,
            partitions=5,
            test=1, # use cross-validation
            selective_stopping=True
        )
    
    print("Estimating unattended TRF...")
    trf_unattended = eelbrain.boosting(
            eeg,
            unattended_envelope,
            -0.100,
            1.000,
            error='l1',
            basis=0.050,
            partitions=5,
            test=1,
            selective_stopping=True
        )
    

    # Save all 4 TRFs
    trf_dir.mkdir(exist_ok=True, parents=True)
    
    eelbrain.save.pickle(trf_attended, trf_attended_path)
    eelbrain.save.pickle(trf_unattended, trf_unattended_path)

    print(f"Saved attended TRF to {trf_attended_path}")
    print(f"Saved unattended TRF to {trf_unattended_path}")
# Out:
# --------------------------------------------------
# Processing subject S1...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S1/S1_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S1/S1_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S2...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S2/S2_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S2/S2_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S3...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S3/S3_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S3/S3_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S4...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S4/S4_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S4/S4_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S5...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S5/S5_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S5/S5_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S6...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S6/S6_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S6/S6_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S7...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S7/S7_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S7/S7_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S8...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
# Estimating unattended TRF...
# Saved attended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S8/S8_attended_preprocessed_eeg.pickle
# Saved unattended TRF to /Users/sylvestereley/Data/cocoha3/TRFs/S8/S8_unattended_preprocessed_eeg.pickle
# --------------------------------------------------
# Processing subject S9...
# EEG: <NDVar: 64 sensor, 192000 time>
# Attended envelope: <NDVar 'attended': 192000 time>
# Unattended envelope: <NDVar 'unattended': 192000 time>
# Estimating attended TRF...
